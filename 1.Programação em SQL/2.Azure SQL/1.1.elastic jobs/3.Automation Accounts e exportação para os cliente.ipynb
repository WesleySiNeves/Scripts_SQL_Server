-- %% [markdown]
-- Hoje será um Start do assunto, pois aqui é um mundo
--
-- ## Automação no Microsoft Azure

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- [https://docs.microsoft.com/pt-br/azure/automation/](https://docs.microsoft.com/pt-br/azure/automation/)
--
-- https://docs.microsoft.com/pt-br/azure/automation/quickstarts/create-account-portal

-- %% [markdown]
-- # <mark>**\# O que é ?**</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # **<mark>\# Quando Utilizar</mark>**

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # **<mark>\# Introdução</mark>**

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- \## Demostração

-- %% [markdown]
-- ## <mark>**As exportaçoes são feitas todas para as Storage accounts**</mark>

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ## <mark>**Todos seguem o mesmo padrão**</mark>

-- %% [markdown]
-- ![](attachment:image.png)
